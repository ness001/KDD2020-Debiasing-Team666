# %%
import seaborn as sns
sns.set()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-664c2edb5a65> in <module>
# ----> 1 df.duplicated(keep='first')
#
# NameError: name 'df' is not defined

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
def show_dup(df,subset):
    '''
    df is pandas dataframe
    subset is the subset cot lumns to define whether duplicate
    '''
    clean_df=df.drop_duplicates(subset=subset,keep=False)
    dup_df=df[~df.apply(tuple,1).isin(clean_df.apply(tuple,1))]
    return dup_df

# %%
show_dup(userft,subset=['user_id'])
# Out:
#       user_id age gender city
# 1466    14818   3      M    3
# 1467    14818   2      M    3
# 5733    23453   5      F    2
# 5734    23453   5      F    5
# 6513    32152   1      F    6
# 6514    32152   2      F    6

# %%
userft[userft.duplicated(subset=['user_id'],keep=False)]
# Out:
#       user_id age gender city
# 1466    14818   3      M    3
# 1467    14818   2      M    3
# 5733    23453   5      F    2
# 5734    23453   5      F    5
# 6513    32152   1      F    6
# 6514    32152   2      F    6

# %%
show_dup(itemft,subset=['item_id'])
# Out:
# Empty DataFrame
# Columns: [item_id, tv0, tv1, tv2, tv3, tv4, tv5, tv6, tv7, tv8, tv9, tv10, tv11, tv12, tv13, tv14, tv15, tv16, tv17, tv18, tv19, tv20, tv21, tv22, tv23, tv24, tv25, tv26, tv27, tv28, tv29, tv30, tv31, tv32, tv33, tv34, tv35, tv36, tv37, tv38, tv39, tv40, tv41, tv42, tv43, tv44, tv45, tv46, tv47, tv48, tv49, tv50, tv51, tv52, tv53, tv54, tv55, tv56, tv57, tv58, tv59, tv60, tv61, tv62, tv63, tv64, tv65, tv66, tv67, tv68, tv69, tv70, tv71, tv72, tv73, tv74, tv75, tv76, tv77, tv78, tv79, tv80, tv81, tv82, tv83, tv84, tv85, tv86, tv87, tv88, tv89, tv90, tv91, tv92, tv93, tv94, tv95, tv96, tv97, tv98, ...]
# Index: []
#
# [0 rows x 257 columns]

# %%
itemft.isnull().sum()
# Out:
# item_id    0
# tv0        0
# tv1        0
# tv2        0
# tv3        0
#           ..
# iv123      0
# iv124      0
# iv125      0
# iv126      0
# iv127      0
# Length: 257, dtype: int64

# %%
from sklearn.metrics.pairwise import cosine_similarity
a=itemft.iloc[:,1:129].to_numpy()
a.shape
cosine_similarity(a,a)
# Out:
# (108916, 128)

# %%
from tqdm import tqdm
import pandas as pd
import random


test_path='../../data/underexpose_test/'
train_path='../../data/underexpose_train/'


now_p=6

col_name=['item_id']
for i in range(0,128):
    col_name.append('tv'+str(i))
for i in range(0,128):
    col_name.append('iv'+str(i))



itemft=pd.read_csv(train_path+'underexpose_item_feat.csv',low_memory=False,names=col_name)
itemft=itemft.replace('[\[\]]','',regex=True)#regex=True is the key
#underexpose_item_feat.apply(lambda x: x.str.replace('[\[\]]',''),axis=1)
userft=pd.read_csv(train_path+'underexpose_user_feat.csv',low_memory=False,names=['user_id','age','gender','city'],dtype=\
                  {'user_id': np.int32,'age':'category','gender':'category','city':'category'})

# %%
itemft.sort_values(['item_id'])
# Out:
#        item_id                   tv0                 tv1                 tv2  \
# 5910         1    1.7666375637054443 -2.3465642929077148 -2.6982970237731934
# 8588         2     2.443206787109375 -4.6307106018066415 -3.8115377426147461
# 95383        3    2.9253344535827637 -3.0964827537536621  3.7253918647766113
# 46686        4    1.7903858423233032 -0.3406373858451843  0.9015148878097534
# 66416        5    1.1966462135314941  0.3298040032386780  0.8499276638031006
# ...        ...                   ...                 ...                 ...
# 73872   117526     5.239702224731445 -1.7486144304275513 -1.0141183137893677
# 66071   117529    0.7625244855880737  5.2090616226196289  3.0873105525970463
# 95934   117531   -1.0116167068481445 -1.2966850996017456  0.7899228334426880
# 14108   117537   -0.4922430217266083 -0.4842198491096497  1.2922697067260742
# 53363   117538  -0.04713066667318344 -0.2766412198543549  0.8157448172569275
#
#                       tv3                 tv4                 tv5  \
# 5910  -2.2688496112823486 -0.5129243135452271  0.3830255866050720
# 8588  -2.4013061523437500 -2.8890886306762691  2.1349654197692867
# 95383 -2.0121698379516597 -1.8720839023590088  2.1409063339233403
# 46686 -0.9476603865623474 -0.8907645940780641 -1.8899708986282349
# 66416 -3.4990830421447754 -1.6462507247924805  0.6702905893325806
# ...                   ...                 ...                 ...
# 73872 -7.2034430503845215 -3.3309924602508545  1.3957061767578125
# 66071  1.0666880607604978  2.9502823352813721 -0.6936706900596619
# 95934 -1.4739112854003906 -0.2090731263160706  0.5139054656028748
# 14108  0.6430247426033020 -0.4843226373195648  0.7392048835754395
# 53363  0.4240083396434784  0.1735194623470306  1.0888452529907229
#
#                       tv6                 tv7                 tv8  ...  \
# 5910   1.5153915882110596 -1.7936565876007080 -3.3750660419464111  ...
# 8588   2.1245512962341309  0.4710888862609863 -5.3208765983581534  ...
# 95383 -0.9457486867904664  1.9132845401763920 -5.8902053833007812  ...
# 46686  2.1230149269104004  0.6955871582031250 -5.1562080383300781  ...
# 66416 -0.4014194011688232  0.0831433534622192 -3.0996298789978027  ...
# ...                   ...                 ...                 ...  ...
# 73872 -1.0232028961181641 -0.3381247222423553 -5.6820673942565927  ...
# 66071 -1.4101630449295044  1.4295246601104736 -3.4360706806182861  ...
# 95934  0.8918763995170593 -0.4543311297893524 -1.8387023210525515  ...
# 14108 -0.0638125240802765  0.3924796283245087 -0.0878265798091888  ...
# 53363 -0.0855925977230072  0.3151774704456329  0.1855995059013367  ...
#
#                     iv118               iv119               iv120  \
# 5910   2.4903695583343506 -2.6618578433990483  1.2282228469848633
# 8588  -5.0327177047729492  0.5266960859298706  0.3979385495185852
# 95383  0.6462442874908447 -1.6235433816909790 -0.3175131082534790
# 46686 -1.7694497108459473 -2.8014276027679443  5.6722269058227539
# 66416  1.5697612762451172  0.8613286614418030  0.4798441827297210
# ...                   ...                 ...                 ...
# 73872 -1.3484240770339966  0.7784362435340881 -2.4188067913055420
# 66071 -1.3611363172531128 -0.2309410274028778 -3.8713669776916495
# 95934  2.6559598445892334 -0.9689857959747314 -1.9245845079421999
# 14108 -0.0526584461331367 -2.3071699142456050  0.5343434214591980
# 53363 -0.5871656537055969 -1.2441723346710205 -2.3057427406311035
#
#                     iv121               iv122               iv123  \
# 5910   2.0381474494934082 -1.1337909698486328 -0.1942588686943054
# 8588  -3.3488011360168457 -0.2675864100456238  0.3592407405376434
# 95383 -2.8889064788818364 -1.1832270622253418 -0.7950440645217896
# 46686  1.3858109712600708  1.9472028017044067 -3.1983299255371094
# 66416 -2.2584881782531738 -1.9074244499206543  0.8104637861251831
# ...                   ...                 ...                 ...
# 73872 -3.2403039932250977 -1.1954808235168457 -0.6239548921585083
# 66071 -2.6296212673187256 -2.1683278083801270 -0.0032592006027699
# 95934  1.1343922615051270  1.8596881628036499 -2.4626612663269043
# 14108 -1.2797977924346924  3.4008533954620361  2.2689847946166992
# 53363 -4.4709024429321289  2.0365486145019531  1.2532832622528076
#
#                     iv124               iv125               iv126  \
# 5910   1.5561858415603638  3.6090559959411621 -0.7044529318809509
# 8588  -1.5038777589797974  0.2579375803470612  0.4374966621398926
# 95383  3.1521463394165039  2.8817834854125977  3.3509860038757324
# 46686  3.6885011196136479  3.6309738159179688  0.3027572333812714
# 66416  2.6588125228881840  1.4982120990753174  2.1399312019348145
# ...                   ...                 ...                 ...
# 73872 -0.3983075022697449  2.0604903697967534  2.1683945655822754
# 66071 -2.3768272399902344  2.4920547008514404  1.2631882429122925
# 95934  3.0120077133178711  2.9051053524017334  0.9669053554534912
# 14108 -2.6612160205841064  3.3359317779541016  0.2111821174621582
# 53363 -1.0652424097061155  2.7745294570922852  3.1647419929504395
#
#                         iv127
# 5910     -0.29612624645233154
# 8588      -1.1778860092163086
# 95383      2.3370420932769775
# 46686      0.3700370192527771
# 66416    0.010898968204855919
# ...                       ...
# 73872     -1.4784924983978271
# 66071       2.859180450439453
# 95934   -0.005981329828500748
# 14108      -1.024261236190796
# 53363      -0.788444995880127
#
# [108916 rows x 257 columns]

# %%
for p in tqdm(range(0,now_p+1)):


    tnc=pd.read_csv(train_path+r'underexpose_train_click-{}.csv'.format(p),low_memory=False,names=['user_id','item_id','time'])
    ttc=pd.read_csv(test_path+r'underexpose_test_click-{}/underexpose_test_click-{}.csv'.format(p,p),low_memory=False\
                   ,names=['user_id','item_id','time'])

    # ttt=pd.read_csv(test_path+'utc_click-{}.csv'.format(p),low_memory=False)
    # ttt.drop(ttt.columns[0],axis=1,inplace=True) # !!
   `
    temp=tnc.merge(itemft,how='left')
    assert tnc.shape[0]==temp.shape[0]

    all_tn=temp.merge(userft,left_on=['user_id'],right_on=['user_id'],how='left')
    assert temp.shape[0] == all_tn.shape[0]
    all_tn.to_csv(train_path+'train_{}.csv'.format(p),index=False)
# Out:
# 100%|██████████| 7/7 [24:43<00:00, 211.94s/it]

# %% [markdown]
# ## get matrix

# %%
from tqdm import tqdm
import pandas as pd
train_path='../data/underexpose_train/'
test_path='../data/underexpose_test/'
now_p=6
df=pd.read_csv('../user_data/'+'train_{}.csv'.format(now_p),low_memory=False)

# %%
item_user_matrix=df.pivot_table(index='item_id',columns='user_id',aggfunc='size',fill_value=0)

# %%
item_user_matrix.shape
# Out:
# (48662, 18575)

# %%
item_user_matrix_min=item_user_matrix.dropna()

# %%
item_user_matrix.to_hdf(train_path+'item_user_matrix.h5',key='result',index=False)
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# <ipython-input-9-ab2235ae326b> in <module>
# ----> 1 item_user_matrix.to_hdf(train_path+'item_user_matrix.h5',key='result',index=False)
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/core/generic.py in to_hdf(self, path_or_buf, key, **kwargs)
#    2528         from pandas.io import pytables
#    2529
# -> 2530         pytables.to_hdf(path_or_buf, key, self, **kwargs)
#    2531
#    2532     def to_msgpack(self, path_or_buf=None, encoding="utf-8", **kwargs):
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/io/pytables.py in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, **kwargs)
#     276             path_or_buf, mode=mode, complevel=complevel, complib=complib
#     277         ) as store:
# --> 278             f(store)
#     279     else:
#     280         f(path_or_buf)
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/io/pytables.py in <lambda>(store)
#     269         f = lambda store: store.append(key, value, **kwargs)
#     270     else:
# --> 271         f = lambda store: store.put(key, value, **kwargs)
#     272
#     273     path_or_buf = _stringify_path(path_or_buf)
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/io/pytables.py in put(self, key, value, format, append, **kwargs)
#     957             format = get_option("io.hdf.default_format") or "fixed"
#     958         kwargs = self._validate_format(format, kwargs)
# --> 959         self._write_to_group(key, value, append=append, **kwargs)
#     960
#     961     def remove(self, key, where=None, start=None, stop=None):
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/io/pytables.py in _write_to_group(self, key, value, format, index, append, complib, encoding, **kwargs)
#    1523
#    1524         # write the object
# -> 1525         s.write(obj=value, append=append, complib=complib, **kwargs)
#    1526
#    1527         if s.is_table and index:
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/io/pytables.py in write(self, obj, **kwargs)
#    3230             blk_items = data.items.take(blk.mgr_locs)
#    3231             self.write_array(
# -> 3232                 "block{idx}_values".format(idx=i), blk.values, items=blk_items
#    3233             )
#    3234             self.write_index("block{idx}_items".format(idx=i), blk_items)
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/pandas/io/pytables.py in write_array(self, key, value, items)
#    3017                     getattr(self.group, key)._v_attrs.value_type = "timedelta64"
#    3018                 else:
# -> 3019                     self._handle.create_array(self.group, key, value)
#    3020
#    3021         getattr(self.group, key)._v_attrs.transposed = transposed
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/tables/file.py in create_array(self, where, name, obj, title, byteorder, createparents, atom, shape, track_times)
#    1157         return Array(parentnode, name,
#    1158                      obj=obj, title=title, byteorder=byteorder,
# -> 1159                      track_times=track_times)
#    1160
#    1161
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/tables/array.py in __init__(self, parentnode, name, obj, title, byteorder, _log, _atom, track_times)
#     191         # Ordinary arrays have no filters: leaf is created with default ones.
#     192         super(Array, self).__init__(parentnode, name, new, Filters(),
# --> 193                                     byteorder, _log, track_times)
#     194
#     195     def _g_create(self):
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/tables/leaf.py in __init__(self, parentnode, name, new, filters, byteorder, _log, track_times)
#     284
#     285
# --> 286         super(Leaf, self).__init__(parentnode, name, _log)
#     287
#     288     def __len__(self):
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/tables/node.py in __init__(self, parentnode, name, _log)
#     262             #   Create or open the node and get its object ID.
#     263             if new:
# --> 264                 self._v_objectid = self._g_create()
#     265             else:
#     266                 self._v_objectid = self._g_open()
#
# ~/anaconda3/envs/newborn/lib/python3.7/site-packages/tables/array.py in _g_create(self)
#     223             # on
#     224             (self._v_objectid, self.shape, self.atom) = self._create_array(
# --> 225                 nparr, self._v_new_title, self.atom)
#     226         except:  # XXX
#     227             # Problems creating the Array on disk. Close node and re-raise.
#
# tables/hdf5extension.pyx in tables.hdf5extension.Array._create_array()
#
# HDF5ExtError: Problems creating the Array.

# %%
df.shape
# Out:
# (310372, 262)

# %%
df.dropna().shape
# Out:
# (71688, 262)

# %% [markdown]
# ## get non-null database

# %%
df_min=df.dropna()

# %%
df_min.to_csv(train_path+'train_min_{}'.format(now_p),index=False)

# %%
df_min=pd.read_csv('../user_data/'+'train_min_{}'.format(now_p))

# %%
database=df_min.copy().drop(['user_id','item_id'],axis=1)
database=database.replace({'M':1,'F':0})
database=database.astype({'age': 'int','gender':'int','city':'int'})
database.head(3)
# Out:
#        time       tv0       tv1       tv2       tv3       tv4       tv5  \
# 0  0.984111  4.148138 -0.213997 -0.274804  0.394361 -2.207227 -1.437607
# 1  0.984263  4.148138 -0.213997 -0.274804  0.394361 -2.207227 -1.437607
# 2  0.984069  5.053555  1.216570  0.348558  0.380879  5.722718 -0.903466
#
#         tv6       tv7       tv8  ...     iv121     iv122     iv123     iv124  \
# 0  2.098062 -0.612489 -4.826493  ... -2.937082 -0.981116  0.425762  1.491055
# 1  2.098062 -0.612489 -4.826493  ... -2.937082 -0.981116  0.425762  1.491055
# 2 -2.930219 -2.049398 -7.384793  ... -1.356675 -1.060216  0.303131  1.582733
#
#       iv125     iv126     iv127  age  gender  city
# 0  3.889630  1.439132 -0.080906    4       0     4
# 1  3.889630  1.439132 -0.080906    4       0     2
# 2  1.423042  2.876045 -0.571884    3       0     5
#
# [3 rows x 260 columns]

# %% [markdown]
# ## true value

# %%
c=6
temp=pd.read_csv(test_path + '/underexpose_test_click-{}/underexpose_test_click-{}.csv'.format(c,c), header=None,  names=['user_id', 'item_id', 'time'])
temp=temp.sort_values(['user_id','time'],ascending=[True,False]).groupby(['user_id']).agg('max').reset_index()
query=temp.merge(itemft,how='left').merge(userft,how='left').drop(['user_id','item_id'],axis=1)
query=query.replace({'M':1,'F':0})
query=query.astype({'age': 'int','gender':'int','city':'int'},errors='ignore')
query.head(3)

query.info()
query.shape
query.select_dtypes(['category'])
query['age'].dtype =='category'

database['age'].median()

summary=database.mean()
for col in query.isna().any().loc[query.isna().any() == True].index:
    if col in ['age','gender','city']:
        a=summary[col]
    else:
        a=database[col].median()
    query[col]=query[col].replace(np.nan,a)
query.shape == query.dropna().shape

query.head()
database.head()

from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
query1=ss.fit_transform(query)
database1=ss.fit_transform(database)
# Out:
#                  time                tv0                 tv1  \
# 0  0.9842771241305298  2.101147174835205 -0.8465766906738281
# 1  0.9842517769474944  1.900734305381775  2.1579475402832031
# 2  0.9842692676835492  1.830065131187439  1.8811055421829224
#
#                   tv2                 tv3                 tv4  \
# 0  0.0573386922478676 -3.1112377643585205 -0.8484025001525879
# 1  3.0377004146575928 -3.0554065704345703  1.2677739858627319
# 2  2.6448986530303955 -2.4803488254547119 -1.0310925245285034
#
#                   tv5                 tv6                 tv7  \
# 0  2.9340057373046875  1.1302022933959959 -0.5584614276885986
# 1 -1.0928924083709717 -3.7414407730102539 -1.1887992620468140
# 2  1.9788519144058228 -1.2319024801254272 -1.8476966619491575
#
#                   tv8  ...               iv121               iv122  \
# 0 -2.9435551166534424  ...  1.5269055366516111 -2.7677159309387207
# 1 -3.2973101139068604  ...  1.0075087547302246 -1.0377058982849119
# 2 -3.5557911396026611  ... -0.2710131108760834  0.2487333118915558
#
#                 iv123               iv124               iv125  \
# 0 -0.5956848263740540  0.1572125703096390  1.0126974582672121
# 1  0.3403505682945251  2.2763986587524414  2.3016302585601807
# 2  2.4548890590667725 -0.1799300462007523  2.5021350383758545
#
#                 iv126                 iv127  age  gender  city
# 0  2.7917819023132324    0.3088803291320801    8     1.0     4
# 1  1.0346159934997561   -0.8432886004447937  NaN     NaN   NaN
# 2  0.2804744839668274   0.44003647565841675  NaN     NaN   NaN
#
# [3 rows x 260 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1821 entries, 0 to 1820
# Columns: 260 entries, time to city
# dtypes: category(2), float64(254), object(4)
# memory usage: 3.6+ MB
# (1821, 260)
#       age city
# 0       8    4
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4       6    1
# ...   ...  ...
# 1816  NaN  NaN
# 1817  NaN  NaN
# 1818  NaN  NaN
# 1819  NaN  NaN
# 1820  NaN  NaN
#
# [1821 rows x 2 columns]
# True
# 4.0
# True
#                  time                 tv0                 tv1  \
# 0  0.9842771241305298   2.101147174835205 -0.8465766906738281
# 1  0.9842517769474944   1.900734305381775  2.1579475402832031
# 2  0.9842692676835492   1.830065131187439  1.8811055421829224
# 3  0.9842643606374868  1.8137321472167969  1.3914031982421875
# 4  0.9842105925855824  0.8316391706466675  1.8352080583572388
#
#                   tv2                 tv3                 tv4  \
# 0  0.0573386922478676 -3.1112377643585205 -0.8484025001525879
# 1  3.0377004146575928 -3.0554065704345703  1.2677739858627319
# 2  2.6448986530303955 -2.4803488254547119 -1.0310925245285034
# 3  2.1369509696960449 -4.1689491271972665 -2.8606204986572266
# 4  1.0361447334289549 -3.9268870353698730 -0.4585402011871338
#
#                   tv5                 tv6                 tv7  \
# 0  2.9340057373046875  1.1302022933959959 -0.5584614276885986
# 1 -1.0928924083709717 -3.7414407730102539 -1.1887992620468140
# 2  1.9788519144058228 -1.2319024801254272 -1.8476966619491575
# 3  1.9786089658737185 -0.2026271671056747 -1.7621158361434937
# 4  0.8195793628692627  3.3453412055969238 -4.2287759780883789
#
#                   tv8  ...               iv121               iv122  \
# 0 -2.9435551166534424  ...  1.5269055366516111 -2.7677159309387207
# 1 -3.2973101139068604  ...  1.0075087547302246 -1.0377058982849119
# 2 -3.5557911396026611  ... -0.2710131108760834  0.2487333118915558
# 3 -3.4887967109680176  ... -1.4988899230957031  1.6837480068206787
# 4 -3.3158850669860840  ...  1.4824553728103638  4.6624727249145508
#
#                 iv123               iv124               iv125  \
# 0 -0.5956848263740540  0.1572125703096390  1.0126974582672121
# 1  0.3403505682945251  2.2763986587524414  2.3016302585601807
# 2  2.4548890590667725 -0.1799300462007523  2.5021350383758545
# 3  1.1026927232742310 -0.2537772655487061  2.9432177543640137
# 4  0.7338652014732361  1.7606782913208008  1.0468974113464355
#
#                 iv126                 iv127                age  \
# 0  2.7917819023132324    0.3088803291320801                  8
# 1  1.0346159934997561   -0.8432886004447937  4.248995647807164
# 2  0.2804744839668274   0.44003647565841675  4.248995647807164
# 3  1.3797429800033569    -0.885633647441864  4.248995647807164
# 4  0.5324596166610718     -0.70954829454422                  6
#
#                gender               city
# 0  1.0000000000000000                  4
# 1  0.1149425287356322  3.674087713424841
# 2  0.1149425287356322  3.674087713424841
# 3  0.1149425287356322  3.674087713424841
# 4  1.0000000000000000                  1
#
# [5 rows x 260 columns]
#                  time                 tv0                 tv1  \
# 0  0.9841110719125040  4.1481380462646484 -0.2139974832534789
# 1  0.9842627512424618  4.1481380462646484 -0.2139974832534789
# 2  0.9840694762116832  5.0535550117492685  1.2165696620941162
# 3  0.9842570189950302  2.9716651439666748 -0.5788695812225342
# 4  0.9840924399002436  0.4042505621910095 -1.0307354927062988
#
#                   tv2                 tv3                 tv4  \
# 0 -0.2748044133186340  0.3943611383438110 -2.2072267532348642
# 1 -0.2748044133186340  0.3943611383438110 -2.2072267532348642
# 2  0.3485578894615173  0.3808794021606445  5.7227177619934073
# 3  2.2469174861907959 -1.7302743196487431 -2.3264360427856445
# 4 -0.3946554064750672 -1.1291629076004028  1.5390796661376951
#
#                   tv5                 tv6                 tv7  \
# 0 -1.4376068115234375  2.0980615615844727 -0.6124892234802246
# 1 -1.4376068115234375  2.0980615615844727 -0.6124892234802246
# 2 -0.9034663438796996 -2.9302191734313965 -2.0493977069854736
# 3 -0.5912094712257385 -2.3438596725463867  0.4770196080207825
# 4  0.4129871129989624 -0.1573128253221512  0.0748407095670700
#
#                   tv8  ...               iv121               iv122  \
# 0 -4.8264927864074716  ... -2.9370822906494136 -0.9811164140701294
# 1 -4.8264927864074716  ... -2.9370822906494136 -0.9811164140701294
# 2 -7.3847928047180176  ... -1.3566752672195437 -1.0602157115936279
# 3 -3.7080161571502690  ...  0.9559630155563354 -0.0576305389404297
# 4 -3.0261974334716801  ... -1.2563368082046509 -1.1090230941772459
#
#                 iv123               iv124               iv125  \
# 0  0.4257615506649017  1.4910547733306885  3.8896303176879878
# 1  0.4257615506649017  1.4910547733306885  3.8896303176879878
# 2  0.3031310141086578  1.5827329158782959  1.4230424165725708
# 3 -2.8185224533081050 -3.0371842384338379  0.8351709246635437
# 4  1.2311370372772217  1.1668357849121094  3.2568092346191406
#
#                 iv126               iv127  age  gender  city
# 0  1.4391320943832395 -0.0809062123298645    4       0     4
# 1  1.4391320943832395 -0.0809062123298645    4       0     2
# 2  2.8760449886322017 -0.5718842148780823    3       0     5
# 3  1.1768972873687744  0.4194931983947754    2       0     5
# 4  2.9602167606353764 -1.0459980964660645    4       0     6
#
# [5 rows x 260 columns]

# %% [markdown]
# ## query records

# %%
temp=temp.sort_values(by=['user_id','time'],ascending=[True,False]).groupby(['user_id']).apply(\
                                                        lambda x : x.nlargest(2,'time').min()).drop(['user_id'],axis=1).reset_index()
temp.head(3) # GET the second last click

query=temp.merge(itemft,how='left').merge(userft,how='left').drop(['user_id','item_id'],axis=1)
query=query.replace({'M':1,'F':0})
query=query.astype({'age': 'int','gender':'int','city':'int'},errors='ignore')
query.head(3)

query.info()
query.shape
query.select_dtypes(['category'])
query['age'].dtype =='category'

database['age'].median()

summary=database.mean()
for col in query.isna().any().loc[query.isna().any() == True].index:
    if col in ['age','gender','city']:
        a=summary[col]
    else:
        a=database[col].median()
    query[col]=query[col].replace(np.nan,a)
query.shape == query.dropna().shape

query.head()
database.head()

from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
query1=ss.fit_transform(query)
database1=ss.fit_transform(database)

# %% [markdown]
# ## find similarity

# %%
user_path='../user_data/'

from numpy import genfromtxt
database1 = genfromtxt(user_path+'database1.csv', delimiter=',')
query1 = genfromtxt(user_path+'query1.csv', delimiter=',')
query1
# Out:
# array([[-1.65853636,  0.42432929, -1.06798817, ..., -0.13081972,
#         -0.20516912, -0.15768494],
#        [-1.65843807, -0.46582549, -0.11851271, ..., -0.13081972,
#         -0.20516912, -0.15768494],
#        [-1.65833978, -0.20378177,  0.36148371, ..., -0.13081972,
#         -0.20516912, -0.15768494],
#        ...,
#        [ 1.82410461,  0.99336521,  0.37027228, ..., -0.13081972,
#         -0.20516912, -0.15768494],
#        [ 1.82420289,  1.30946385,  1.13300477, ..., -0.13081972,
#         -0.20516912, -0.15768494],
#        [ 1.82430118,  1.75579629,  1.54891634, ..., -0.13081972,
#         -0.20516912, -0.15768494]])

# %%
user_id=genfromtxt(user_path+'user_id.csv',delimiter=',').reshape(-1,1)

# %%
database1.shape
query1.shape
user_id.shape
# Out:
# (5984, 260)
# (12081, 262)
# (12081, 1)

# %%
query1=np.delete(query1,[0,1],1)

# %%
import faiss

database1.dtype
database1=np.ascontiguousarray(database1.astype('float32'))
query1=np.ascontiguousarray(query1.astype('float32'))



dim=260
k=50 # recall 10
nlist=100
quantizer = faiss.IndexFlatL2(dim)
idx=faiss.IndexIVFPQ(quantizer,dim,nlist,10,8)
idx.nprobe =10

# index_sim.add(np.ascontiguousarray(tr_features_np))


idx.train(np.ascontiguousarray(database1))
idx.add(np.ascontiguousarray(database1))
d,i=idx.search(np.ascontiguousarray(query1),100)
# Out:
# dtype('float64')

# %%
result=np.ndarray(shape=d.shape)

# %%
i.shape
# Out:
# (12081, 100)

# %%
df_min=pd.read_csv(user_path+'df_min.csv')
df_min.head(3)
# Out:
#    user_id  item_id                time                 tv0  \
# 0       10    88804  0.9842770799683772  6.0212249755859375
# 1       13    42888  0.9842780035882582 -0.6111484169960022
# 2       16    73359  0.9842585274479918 -0.1482433378696441
#
#                   tv1                 tv2                 tv3  \
# 0 -4.5798912048339844  3.2130193710327148 -2.1399679183959961
# 1 -0.1359649300575257  3.6519391536712646 -1.3654018640518188
# 2  3.3703970909118652  1.3680076599121094 -1.4550262689590454
#
#                   tv4                 tv5                 tv6  ...  \
# 0 -0.9064429402351379  2.4552919864654541  0.9194136857986450  ...
# 1  0.9543317556381226 -1.1697646379470823  2.4903392791748047  ...
# 2  2.8250017166137682 -2.0104930400848398 -4.0500035285949716  ...
#
#                 iv121               iv122               iv123  \
# 0 -1.8558883666992188  1.1678773164749146  1.3769862651824951
# 1 -2.1855368614196777  1.3929390907287598 -0.0513036102056503
# 2 -1.3966966867446899 -0.9993148446083068  0.7488551735877991
#
#                 iv124               iv125               iv126  \
# 0 -3.4025032520294189  1.5410439968109131  3.6849513053894039
# 1  0.0396473109722138  2.7789900302886963  2.3467061519622803
# 2  1.6849117279052734  3.7666616439819336  2.0998668670654297
#
#                 iv127  age  gender  city
# 0  2.9092373847961426    6       F     1
# 1 -0.6091269850730896    7       M     6
# 2 -2.2072551250457764    6       F     2
#
# [3 rows x 262 columns]

# %%
df_min.shape
# Out:
# (5984, 262)

# %%
a=np.ndarray((1,2))*np.nan

# %%
b=np.array([[1,2]])

# %%
a
# Out:
# array([[nan, nan]])

# %%
np.concatenate([a,b])
# Out:
# array([[nan, nan],
#        [ 1.,  2.]])

# %%
for row_i in tqdm(range(len(d))):
    result[row_i]=df_min.loc[i[row_i],'item_id'].values
# Out:
# 100%|██████████| 12081/12081 [00:12<00:00, 961.08it/s]

# %%
result
# Out:
# array([[ 69359.,  50909.,   5099., ...,  10255.,  93590.,  47448.],
#        [ 51505.,  92384.,  18071., ..., 101172.,  30208.,  90430.],
#        [ 72872., 106214.,  72108., ...,  92873.,  63028.,  25356.],
#        ...,
#        [ 23012.,  26666., 102702., ...,  23614.,  69029.,   7264.],
#        [101786.,  55365., 108477., ..., 107396.,  87163.,  58509.],
#        [108744., 111098., 111189., ..., 107032.,  52206., 115323.]])

# %%
resultdf=pd.DataFrame(result,columns=['col'+ str(i) for i in range(0,100)])

# %%
resultdf.head()
# Out:
#        col0      col1     col2     col3      col4      col5      col6  \
# 0   69359.0   50909.0   5099.0  21671.0    4685.0   36760.0    2997.0
# 1   51505.0   92384.0  18071.0  67625.0   99693.0   97339.0   81417.0
# 2   72872.0  106214.0  72108.0  92002.0   77056.0    8207.0    8207.0
# 3  101786.0   52526.0  55365.0  39885.0   96240.0  108477.0  108477.0
# 4   43555.0   53413.0  17460.0  82329.0  113135.0   42193.0   53413.0
#
#        col7     col8     col9  ...     col90    col91     col92     col93  \
# 0   46494.0  23409.0  81561.0  ...   46335.0  19248.0   27133.0   17019.0
# 1   45621.0  55194.0  52342.0  ...  106510.0  40460.0   89179.0  105452.0
# 2    8207.0  26223.0  62422.0  ...   78868.0  63028.0    6969.0   76562.0
# 3   75373.0  88653.0  44114.0  ...   81217.0  75182.0   57934.0   46368.0
# 4  113135.0  11933.0  46983.0  ...   70204.0  91294.0  105391.0  111639.0
#
#       col94    col95     col96     col97    col98     col99
# 0   16780.0  48284.0   83784.0   10255.0  93590.0   47448.0
# 1   49125.0  75373.0  113694.0  101172.0  30208.0   90430.0
# 2   76562.0  76562.0   92433.0   92873.0  63028.0   25356.0
# 3   31323.0  30208.0  110812.0   67910.0  45587.0  101295.0
# 4  112830.0  28993.0   44775.0   71158.0  86504.0   28571.0
#
# [5 rows x 100 columns]

# %%
top50_click = df_min['item_id'].value_counts().index[:50].values

top50_click=list(top50_click)

# %%
set([2,3,5,7])-set([2,3,6])
# Out:
# {5, 7}

# %%
result_filled=np.ndarray(shape=(d.shape[0],50))

sm=0
row_i=0
for item in list(map(set,resultdf.values)):
    diff=50-len(item)
    if diff>=0:
        result_filled[row_i]=list(item)+random.sample(list(set(top50_click)-item),diff)
        if len(list(set(top50_click)-item))<diff:
            print('ooooops')
            random.sample(list(set(top50_click)-item),diff)
        sm+=1
    else:
        result_filled[row_i]=list(item)[:50]
        
    row_i=row_i+1

        
sm
result_filled.shape == d.shape
# Out:
# 0
# False

# %%
result_filled.shape
# Out:
# (12081, 50)

# %%
user_id.shape
# Out:
# (12081, 1)

# %%
d.shape
# Out:
# (12081, 100)

# %%
result_filled=np.concatenate((user_id,result_filled),axis=1)

# %%
result_filled.shape
# Out:
# (12081, 51)

# %%
np.savetxt('underexpose_submit-6.csv',result_filled,delimiter=',',fmt='%i')
