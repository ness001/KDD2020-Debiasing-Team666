# %%
# !python -m pip install "dask[complete]"
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting dask[complete]
#   Downloading https://mirrors.aliyun.com/pypi/packages/c4/1c/64d277a1aa181ff845327c7ad405f020c58543be005b9bc252f2141d8110/dask-2.17.2-py3-none-any.whl (813 kB)
#      |################################| 813 kB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from dask[complete]) (5.3.1)
# Requirement already satisfied: numpy>=1.13.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]) (1.16.4)
# Collecting partd>=0.3.10; extra == "complete"
#   Downloading https://mirrors.aliyun.com/pypi/packages/44/e1/68dbe731c9c067655bff1eca5b7d40c20ca4b23fd5ec9f3d17e201a6f36b/partd-1.1.0-py3-none-any.whl (19 kB)
# Collecting bokeh>=1.0.0; extra == "complete"
#   Downloading https://mirrors.aliyun.com/pypi/packages/30/cf/9bef843880084b646cf5e6988e8f0aa081dccdf09f1617cfc6755f9a3353/bokeh-2.0.2.tar.gz (8.6 MB)
#      |################################| 8.6 MB 1.7 MB/s eta 0:00:01
# Collecting distributed>=2.0; extra == "complete"
#   Downloading https://mirrors.aliyun.com/pypi/packages/40/43/7f0181ff095961f99f436ab0b97239f07f4accb67837783f7ddddb414f32/distributed-2.17.0-py3-none-any.whl (638 kB)
#      |################################| 638 kB 30.7 MB/s eta 0:00:01
# Collecting fsspec>=0.6.0; extra == "complete"
#   Downloading https://mirrors.aliyun.com/pypi/packages/0f/31/f27a81686b2f1b2f6776bd5db10efc7d88f28a50e8888f55409ef6501a50/fsspec-0.7.4-py3-none-any.whl (75 kB)
#      |################################| 75 kB 32.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]) (1.0.4)
# Collecting cloudpickle>=0.2.2; extra == "complete"
#   Downloading https://mirrors.aliyun.com/pypi/packages/c6/a5/bb99276ec2685e11d34e4aefc0d9238626843ea51f974aa59c68317d34b2/cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting toolz>=0.8.2; extra == "complete"
#   Downloading https://mirrors.aliyun.com/pypi/packages/22/8e/037b9ba5c6a5739ef0dcde60578c64d49f45f64c5e5e886531bfbc39157f/toolz-0.10.0.tar.gz (49 kB)
#      |################################| 49 kB 53.8 MB/s eta 0:00:01
# Collecting locket
#   Downloading https://mirrors.aliyun.com/pypi/packages/d0/22/3c0f97614e0be8386542facb3a7dcfc2584f7b83608c02333bced641281c/locket-0.2.0.tar.gz (3.5 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]) (2.8.1)
# Requirement already satisfied: Jinja2>=2.7 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]) (2.11.2)
# Requirement already satisfied: pillow>=4.0 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]) (7.1.1)
# Collecting packaging>=16.8
#   Downloading https://mirrors.aliyun.com/pypi/packages/46/19/c5ab91b1b05cfe63cccd5cfc971db9214c6dd6ced54e33c30d5af1d2bc43/packaging-20.4-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]) (6.0.4)
# Requirement already satisfied: typing_extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]) (3.7.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]) (46.1.3)
# Collecting psutil>=5.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/c4/b8/3512f0e93e0db23a71d82485ba256071ebef99b227351f0f5540f744af41/psutil-5.7.0.tar.gz (449 kB)
#      |################################| 449 kB 39.5 MB/s eta 0:00:01
# Requirement already satisfied: contextvars; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]) (2.4)
# Collecting click>=6.6
#   Downloading https://mirrors.aliyun.com/pypi/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |################################| 82 kB 19.6 MB/s eta 0:00:01
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/13/f3/cf85f7c3a2dbd1a515d51e1f1676d971abe41bba6f4ab5443240d9a78e5b/sortedcontainers-2.1.0-py2.py3-none-any.whl (28 kB)
# Collecting tblib>=1.6.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/0d/de/dca3e651ca62e59c08d324f4a51467fa4b8cbeaafb883b5e83720b4d4a47/tblib-1.6.0-py2.py3-none-any.whl (12 kB)
# Collecting zict>=0.1.3
#   Downloading https://mirrors.aliyun.com/pypi/packages/5a/65/0f743c740c30cace984ef8ff96fd1e991083fa884900a8aad3efff3252b9/zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting msgpack>=0.6.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/c9/35/33aa1af0700d21beabdf74373f31c52c048be8ee082f98edbc37ba3ae956/msgpack-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (274 kB)
#      |################################| 274 kB 32.1 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "complete"->dask[complete]) (2020.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.1->bokeh>=1.0.0; extra == "complete"->dask[complete]) (1.14.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.7->bokeh>=1.0.0; extra == "complete"->dask[complete]) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=16.8->bokeh>=1.0.0; extra == "complete"->dask[complete]) (2.4.7)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars; python_version < "3.7"->distributed>=2.0; extra == "complete"->dask[complete]) (0.14)
# Collecting heapdict
#   Downloading https://mirrors.aliyun.com/pypi/packages/b6/9d/cd4777dbcf3bef9d9627e0fe4bc43d2e294b1baeb01d0422399d5e9de319/HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: bokeh, toolz, locket, psutil
#   Building wheel for bokeh (setup.py) ... done
#   Created wheel for bokeh: filename=bokeh-2.0.2-py3-none-any.whl size=9075630 sha256=ad542edbb271da83b800f54ae1fe84785fbf3318e70eee182fe5848d561074b9
#   Stored in directory: /root/.cache/pip/wheels/37/d8/09/4c29de6a5f82f3f3523ad16227baa4fc1c79c77680806b7ed0
#   Building wheel for toolz (setup.py) ... done
#   Created wheel for toolz: filename=toolz-0.10.0-py3-none-any.whl size=57158 sha256=53a59feb47219ec7558c14e10b5cbaf8633b15646e6e163052af4ec23e276103
#   Stored in directory: /root/.cache/pip/wheels/85/f5/aa/fcee5ca3b0aaea2f12cae69e468ca98b3820a75617e3e6b554
#   Building wheel for locket (setup.py) ... done
#   Created wheel for locket: filename=locket-0.2.0-py3-none-any.whl size=4479 sha256=7cc05f9d3fd7432053859e5c0e07b2f18dbff8a3738a25bdb845036149534b91
#   Stored in directory: /root/.cache/pip/wheels/48/6c/b5/5ed278f5d750d8cd339c75bee7e85d27f7e34fba30f736d7c8
#   Building wheel for psutil (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-j_6ijk2s/psutil/setup.py'"'"'; __file__='"'"'/tmp/pip-install-j_6ijk2s/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-qup4ef42
#        cwd: /tmp/pip-install-j_6ijk2s/psutil/
#   Complete output (42 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.6
#   creating build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_pswindows.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psbsd.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_compat.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_common.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psposix.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/__init__.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psaix.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_pslinux.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_pssunos.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psosx.py -> build/lib.linux-x86_64-3.6/psutil
#   creating build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_aix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_system.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_bsd.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_connections.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_unicode.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_posix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_windows.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_misc.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_sunos.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/__init__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_memory_leaks.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_osx.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_process.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_linux.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/__main__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_contracts.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/runner.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   running build_ext
#   building 'psutil._psutil_linux' extension
#   creating build/temp.linux-x86_64-3.6
#   creating build/temp.linux-x86_64-3.6/psutil
#   x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DPSUTIL_POSIX=1 -DPSUTIL_SIZEOF_PID_T=4 -DPSUTIL_VERSION=570 -DPSUTIL_LINUX=1 -I/usr/include/python3.6m -c psutil/_psutil_common.c -o build/temp.linux-x86_64-3.6/psutil/_psutil_common.o
#   psutil/_psutil_common.c:9:20: fatal error: Python.h: No such file or directory
#   compilation terminated.
#   error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for psutil
#   Running setup.py clean for psutil
# Successfully built bokeh toolz locket
# Failed to build psutil
# Installing collected packages: locket, toolz, partd, packaging, bokeh, cloudpickle, psutil, click, sortedcontainers, tblib, heapdict, zict, msgpack, distributed, fsspec, dask
#     Running setup.py install for psutil ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-j_6ijk2s/psutil/setup.py'"'"'; __file__='"'"'/tmp/pip-install-j_6ijk2s/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-pwfuwjsd/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.6/psutil
#          cwd: /tmp/pip-install-j_6ijk2s/psutil/
#     Complete output (42 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.6
#     creating build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_pswindows.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psbsd.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_compat.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_common.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psposix.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/__init__.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psaix.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_pslinux.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_pssunos.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psosx.py -> build/lib.linux-x86_64-3.6/psutil
#     creating build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_aix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_system.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_bsd.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_connections.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_unicode.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_posix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_windows.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_misc.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_sunos.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/__init__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_memory_leaks.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_osx.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_process.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_linux.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/__main__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_contracts.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/runner.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     running build_ext
#     building 'psutil._psutil_linux' extension
#     creating build/temp.linux-x86_64-3.6
#     creating build/temp.linux-x86_64-3.6/psutil
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DPSUTIL_POSIX=1 -DPSUTIL_SIZEOF_PID_T=4 -DPSUTIL_VERSION=570 -DPSUTIL_LINUX=1 -I/usr/include/python3.6m -c psutil/_psutil_common.c -o build/temp.linux-x86_64-3.6/psutil/_psutil_common.o
#     psutil/_psutil_common.c:9:20: fatal error: Python.h: No such file or directory
#     compilation terminated.
#     error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-j_6ijk2s/psutil/setup.py'"'"'; __file__='"'"'/tmp/pip-install-j_6ijk2s/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-pwfuwjsd/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.6/psutil Check the logs for full command output.
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle
from loguru import logger
import argparse


class PickleWrapper(object):

    @classmethod
    def loadFromFile(cls, file, mode='rb'):
        with open(file, mode) as f:
            return pickle.load(f)

    @classmethod
    def dump2File(cls, o, file, mode='wb'):
        '''
        把目标对象序列化到文件
        :param o: 目标对象
        :param file: 文件
        :param mode:
        :return:
        '''
        with open(file, mode) as f:
            pickle.dump(o, f,protocol=pickle.HIGHEST_PROTOCOL)

# %%
parser = argparse.ArgumentParser(description='t')
parser.add_argument('--now_phase', type=int, default=6, help='')
parser.add_argument('--window', type=int, default=10, help='cocur_matr的时间窗')
parser.add_argument('--time_decay', type=float, default=7/8, help='时间衰减')
parser.add_argument('--mode', type=str, default='train', help='train test')
parser.add_argument('--topk', type=int, default=500, help='每种召回策略召回的样本数')
parser.add_argument('--DATA_DIR', type=str, default='./', help='data dir')

args = parser.parse_args(args=[])
trace = logger.add(os.path.join(args.DATA_DIR, 'data_gen/runtime.log'))

# Cell
def load_click_data_per_phase(now_phase, base_dir):
    """
    """
    train_path = os.path.join(base_dir)
    test_path = os.path.join(base_dir)

    all_click_df = []
    for c in range(now_phase + 1):
        logger.info(f'phase: {c}')
        cols_str = 'user_id item_id time'.split()
        click_train1 = pd.read_csv(train_path + '/underexpose_train_click-{}.csv'.format(c), header=None,  names=['user_id', 'item_id', 'time'], converters={c: str for c in cols_str})
        click_test1 = pd.read_csv(test_path + '/underexpose_test_click-{}.csv'.format(c), header=None,  names=['user_id', 'item_id', 'time'], converters={c: str for c in cols_str})
        test_qtime1 = pd.read_csv(test_path + 'underexpose_test_qtime-{}.csv'.format(c), header=None,  names=['user_id','time'], converters={c: str for c in cols_str})
        click_test1_val = click_test1.sort_values(['user_id', 'time']).drop_duplicates(subset=['user_id'],keep='last')

        click_test1 = click_test1[~click_test1.index.isin(click_test1_val.index)]
        all_click = click_train1.append(click_test1).drop_duplicates().sort_values('time')

        all_click_df.append((all_click, click_test1_val, test_qtime1))
        logger.info(f'all_click: {all_click.shape}, click_test1_val: {click_test1_val.shape}, test_qtime1: {test_qtime1.shape}')
    return all_click_df

all_click_df = load_click_data_per_phase(args.now_phase, args.DATA_DIR)
# Out:
# 2020-06-02 23:11:44.566 | INFO     | __main__:load_click_data_per_phase:21 - phase: 0
# 2020-06-02 23:11:45.200 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (261337, 3), click_test1_val: (1663, 3), test_qtime1: (1663, 2)
# 2020-06-02 23:11:45.202 | INFO     | __main__:load_click_data_per_phase:21 - phase: 1
# 2020-06-02 23:11:45.844 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (264871, 3), click_test1_val: (1726, 3), test_qtime1: (1726, 2)
# 2020-06-02 23:11:45.846 | INFO     | __main__:load_click_data_per_phase:21 - phase: 2
# 2020-06-02 23:11:46.496 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (264624, 3), click_test1_val: (1690, 3), test_qtime1: (1690, 2)
# 2020-06-02 23:11:46.497 | INFO     | __main__:load_click_data_per_phase:21 - phase: 3
# 2020-06-02 23:11:47.186 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (286609, 3), click_test1_val: (1675, 3), test_qtime1: (1675, 2)
# 2020-06-02 23:11:47.188 | INFO     | __main__:load_click_data_per_phase:21 - phase: 4
# 2020-06-02 23:11:47.888 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (291672, 3), click_test1_val: (1708, 3), test_qtime1: (1708, 2)
# 2020-06-02 23:11:47.889 | INFO     | __main__:load_click_data_per_phase:21 - phase: 5
# 2020-06-02 23:11:48.669 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (313378, 3), click_test1_val: (1798, 3), test_qtime1: (1798, 2)
# 2020-06-02 23:11:48.670 | INFO     | __main__:load_click_data_per_phase:21 - phase: 6
# 2020-06-02 23:11:49.525 | INFO     | __main__:load_click_data_per_phase:32 - all_click: (337339, 3), click_test1_val: (1821, 3), test_qtime1: (1821, 2)

# %%
def get_item_data():
    train_item_df = pd.read_csv(os.path.join(args.DATA_DIR, 'underexpose_item_feat.csv'),
                                names=['item_id']+list(range(256)),
                                converters={'item_id':str})
    train_item_df=train_item_df.replace('[\[\]]','',regex=True)
    train_item_df.iloc[:, -1] = train_item_df.iloc[:, -1].map(float)
    return train_item_df
item_feat = get_item_data()

item_feat['text_vec'] = item_feat.iloc[:, 1:129].values.tolist()
item_feat['img_vec'] = item_feat.iloc[:, 129:257].values.tolist()

# item_feat.set_index('item_id', inplace=True)

# %%
from pathlib import Path
Path('./user_data/recall.pkl').stat().st_size
# Out:
# 706078921

# %%
pkl_list = PickleWrapper.loadFromFile('./user_data/recall.pkl')

r_itemcf, r_binn, r_itemcf_yl = pkl_list[0],pkl_list[1],pkl_list[2]

# %%
def load_match_items():
    r_itemcf = PickleWrapper.loadFromFile('./user_data/r_list_itemcf_0527.pkl')

    r_binn = PickleWrapper.loadFromFile('./user_data/r_list_binn_0527.pkl')

#     r_itemcf_phase4 = PickleWrapper.loadFromFile(os.path.join(args.DATA_DIR, 'data_gen/r_list_itemcf_0527_phase4.pkl'))

#     r_binn_phase4 = PickleWrapper.loadFromFile(os.path.join(args.DATA_DIR, 'data_gen/r_list_binn_0527_phase4.pkl'))


    r_itemcf_yl = PickleWrapper.loadFromFile('./user_data/r_list_itemcf_yulao_0527.pkl')

    # r_itemcf = r_itemcf + r_itemcf_phase4
    # r_binn = r_binn + r_binn_phase4
    r_itemcf_yl = [r_itemcf_yl[0], r_itemcf_yl[1],r_itemcf_yl[2],r_itemcf_yl[3],r_itemcf_yl[5],r_itemcf_yl[6],r_itemcf_yl[4]]
    return r_itemcf, r_binn, r_itemcf_yl
#     return r_itemcf_phase4, r_binn_phase4, [r_itemcf_yl[4]]



match_num = 500
r_itemcf, r_binn, r_itemcf_yl = load_match_items()

# %%
        
phase = [0, 1, 2, 3, 5, 6]
match_num=500
mode='train'
itemcf, r_binn, r_itemcf_yl = [r_itemcf, r_binn, r_itemcf_yl]
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
for i in range(len(phase)):
    r_itemcf[i]['phase'] = phase[i]
    r_binn[i]['phase'] = phase[i]
    r_itemcf_yl[i]['phase'] = phase[i]
    df1 = df1.append(r_itemcf[i])
    df2 = df2.append(r_binn[i])
    df3 = df3.append(r_itemcf_yl[i])

df1_ = df1[df1['rank']<(match_num+1)]
df2_ = df2[df2['rank']<(match_num+1)]
df3_ = df3[df3['rank']<(match_num+1)]

print('merge Multi-channel recall...')
cols = 'user_id item_id_pred phase'.split()

if mode == 'train':
    cols = 'user_id item_id_pred item_id_true phase'.split()
df = pd.merge(pd.merge(df1_, df2_, on=cols, how='outer'),
              df3_, on=cols, how='outer')

df = df.fillna(0)
if mode == 'train':
    df['label'] = (df['item_id_pred'] == df['item_id_true']).map(int)


dft = pd.DataFrame()
for p in tqdm(phase):
    # 获取test用户的近n次点击
    temp_ = all_click_df[p][0][all_click_df[p][0].user_id.isin(all_click_df[p][1].user_id)].groupby('user_id')['item_id'].agg(list)
    temp_ = pd.DataFrame(temp_)
    for i in range(0, 5):
        temp_[f'last_{i+1}'] = temp_.item_id.str.get(-(i+1))
    dft = dft.append(temp_.reset_index())
    # 计算每个phase的item_id cnt
    t_ = all_click_df[p][0].groupby('item_id')['user_id'].count()
    df.loc[df.phase==p, 'item_cnt'] = df.item_id_pred.map(lambda x: t_[x] if x in t_ else 0)
# Out:
# merge Multi-channel recall...
# 100%|██████████| 6/6 [08:10<00:00, 81.69s/it]

# %%
import multiprocessing
num_processes=multiprocessing.cpu_count()
num_processes
# Out:
# 64

# %%
df = pd.merge(df, dft.drop(columns='item_id'))
df['item_id_pred_text_vec']=0
df['item_id_pred_img_vec']=0

tol=df.shape[0]
item_ft_list=item_feat.item_id.unique()

# %%
chunk_size = int(df.shape[0]/num_processes)

# %%
chunks = [df.iloc[df.index[i:i + chunk_size]] for i in range(0, df.shape[0], chunk_size)]

# %%
# !python -m pip install "dask[dataframe]" --upgrade
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already up-to-date: dask[dataframe] in /usr/local/lib/python3.6/dist-packages (2.17.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (5.3.1)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (0.10.0)
# Collecting fsspec>=0.6.0; extra == "dataframe"
#   Downloading https://mirrors.aliyun.com/pypi/packages/0f/31/f27a81686b2f1b2f6776bd5db10efc7d88f28a50e8888f55409ef6501a50/fsspec-0.7.4-py3-none-any.whl (75 kB)
#      |################################| 75 kB 3.6 MB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: partd>=0.3.10; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.16.4)
# Requirement already satisfied, skipping upgrade: pandas>=0.23.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.0.4)
# Requirement already satisfied, skipping upgrade: locket in /usr/local/lib/python3.6/dist-packages (from partd>=0.3.10; extra == "dataframe"->dask[dataframe]) (0.2.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2.8.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (1.14.0)
# Installing collected packages: fsspec
# Successfully installed fsspec-0.7.4
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import dask.dataframe as ddf
df_dask=ddf.from_pandas(df,npartitions=64)

# %%
df_dask['item_id_pred_text_vec'] = df_dask.item_id_pred.map(lambda x: item_feat['text_vec'][x] if x in item_feat['text_vec'] else np.zeros(128))
df_dask['item_id_pred_img_vec'] = df_dask.item_id_pred.map(lambda x: item_feat['img_vec'][x] if x in item_feat['img_vec'] else np.arange(128))

.compute(scheduler='multiprocessing')

# %%
for c in tqdm('last_1 last_2 last_3'.split()):
    df_dask[f'{c}_text_vec'] = df_dask.item_id_pred.map_partitions(lambda x: item_feat['text_vec'][x] if x in item_feat['text_vec'] else np.zeros(128), meta=('item_id',str)).compute(scheduler='multiprocessing')

    df_dask[f'{c}_img_vec'] = df_dask.item_id_pred.map_partitions(lambda x: item_feat['img_vec'][x] if x in item_feat['img_vec'] else np.arange(128), meta=('item_id',str)).compute(scheduler='multiprocessing')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]Exception ignored in: <Finalize object, dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 571, in _terminate_pool
#     cls._help_stuff_finish(inqueue, task_handler, len(pool))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 556, in _help_stuff_finish
#     inqueue._rlock.acquire()
# KeyboardInterrupt:
#   0%|          | 0/3 [01:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/dask/base.py in normalize_function(func)
#     722     try:
# --> 723         return function_cache[func]
#     724     except KeyError:
#
# KeyError: <function <lambda> at 0x7f76b8053840>
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-066f3247fceb> in <module>
#       1 for c in tqdm('last_1 last_2 last_3'.split()):
# ----> 2     df_dask[f'{c}_text_vec'] = df_dask.item_id_pred.map_partitions(lambda x: item_feat['text_vec'][x] if x in item_feat['text_vec'] else np.zeros(128), meta=('item_id',str)).compute(scheduler='multiprocessing')
#       3
#       4     df_dask[f'{c}_img_vec'] = df_dask.item_id_pred.map_partitions(lambda x: item_feat['img_vec'][x] if x in item_feat['img_vec'] else np.arange(128), meta=('item_id',str)).compute(scheduler='multiprocessing')
#       5
#
# /usr/local/lib/python3.6/dist-packages/dask/dataframe/core.py in map_partitions(self, func, *args, **kwargs)
#     639         >>> ddf.map_partitions(func).clear_divisions()  # doctest: +SKIP
#     640         """
# --> 641         return map_partitions(func, self, *args, **kwargs)
#     642
#     643     @insert_meta_param_description(pad=12)
#
# /usr/local/lib/python3.6/dist-packages/dask/dataframe/core.py in map_partitions(func, meta, enforce_metadata, transform_divisions, *args, **kwargs)
#    5090     else:
#    5091         name = funcname(func)
# -> 5092         token = tokenize(func, meta, *args, **kwargs)
#    5093     name = "{0}-{1}".format(name, token)
#    5094
#
# /usr/local/lib/python3.6/dist-packages/dask/base.py in tokenize(*args, **kwargs)
#     668     if kwargs:
#     669         args = args + (kwargs,)
# --> 670     return md5(str(tuple(map(normalize_token, args))).encode()).hexdigest()
#     671
#     672
#
# /usr/local/lib/python3.6/dist-packages/dask/utils.py in __call__(self, arg, *args, **kwargs)
#     504         """
#     505         meth = self.dispatch(type(arg))
# --> 506         return meth(arg, *args, **kwargs)
#     507
#     508     @property
#
# /usr/local/lib/python3.6/dist-packages/dask/base.py in normalize_object(o)
#     712     if method is not None:
#     713         return method()
# --> 714     return normalize_function(o) if callable(o) else uuid.uuid4().hex
#     715
#     716
#
# /usr/local/lib/python3.6/dist-packages/dask/base.py in normalize_function(func)
#     723         return function_cache[func]
#     724     except KeyError:
# --> 725         result = _normalize_function(func)
#     726         if len(function_cache) >= 500:  # clear half of cache if full
#     727             with function_cache_lock:
#
# /usr/local/lib/python3.6/dist-packages/dask/base.py in _normalize_function(func)
#     759             import cloudpickle
#     760
# --> 761             return cloudpickle.dumps(func, protocol=0)
#     762         except Exception:
#     763             return str(func)
#
# /usr/local/lib/python3.6/dist-packages/cloudpickle/cloudpickle.py in dumps(obj, protocol)
#    1081     try:
#    1082         cp = CloudPickler(file, protocol=protocol)
# -> 1083         cp.dump(obj)
#    1084         return file.getvalue()
#    1085     finally:
#
# /usr/local/lib/python3.6/dist-packages/cloudpickle/cloudpickle.py in dump(self, obj)
#     475         self.inject_addons()
#     476         try:
# --> 477             return Pickler.dump(self, obj)
#     478         except RuntimeError as e:
#     479             if 'recursion' in e.args[0]:
#
# /usr/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/local/lib/python3.6/dist-packages/cloudpickle/cloudpickle.py in save_function(self, obj, name)
#     542             return self.save_pypy_builtin_func(obj)
#     543         else:
# --> 544             return self.save_function_tuple(obj)
#     545
#     546     dispatch[types.FunctionType] = save_function
#
# /usr/local/lib/python3.6/dist-packages/cloudpickle/cloudpickle.py in save_function_tuple(self, func)
#     754         if hasattr(func, '__kwdefaults__'):
#     755             state['kwdefaults'] = func.__kwdefaults__
# --> 756         save(state)
#     757         write(pickle.TUPLE)
#     758         write(pickle.REDUCE)  # applies _fill_function on the tuple
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     833             for k, v in items:
#     834                 save(k)
# --> 835                 save(v)
#     836                 write(SETITEM)
#     837             return
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     833             for k, v in items:
#     834                 save(k)
# --> 835                 save(v)
#     836                 write(SETITEM)
#     837             return
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_dict(self, obj)
#     819
#     820         self.memoize(obj)
# --> 821         self._batch_setitems(obj.items())
#     822
#     823     dispatch[dict] = save_dict
#
# /usr/lib/python3.6/pickle.py in _batch_setitems(self, items)
#     833             for k, v in items:
#     834                 save(k)
# --> 835                 save(v)
#     836                 write(SETITEM)
#     837             return
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_tuple(self, obj)
#     749         write(MARK)
#     750         for element in obj:
# --> 751             save(element)
#     752
#     753         if id(obj) in memo:
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     792         if not self.bin:
#     793             for x in items:
# --> 794                 save(x)
#     795                 write(APPEND)
#     796             return
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     519
#     520         # Save the reduce() output and finally memoize the object
# --> 521         self.save_reduce(obj=obj, *rv)
#     522
#     523     def persistent_id(self, obj):
#
# /usr/lib/python3.6/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632
#     633         if state is not None:
# --> 634             save(state)
#     635             write(BUILD)
#     636
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_tuple(self, obj)
#     749         write(MARK)
#     750         for element in obj:
# --> 751             save(element)
#     752
#     753         if id(obj) in memo:
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     792         if not self.bin:
#     793             for x in items:
# --> 794                 save(x)
#     795                 write(APPEND)
#     796             return
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_list(self, obj)
#     779
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#     783     dispatch[list] = save_list
#
# /usr/lib/python3.6/pickle.py in _batch_appends(self, items)
#     792         if not self.bin:
#     793             for x in items:
# --> 794                 save(x)
#     795                 write(APPEND)
#     796             return
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     474         f = self.dispatch.get(t)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#     478
#
# /usr/lib/python3.6/pickle.py in save_float(self, obj)
#     682             self.write(BINFLOAT + pack('>d', obj))
#     683         else:
# --> 684             self.write(FLOAT + repr(obj).encode("ascii") + b'\n')
#     685     dispatch[float] = save_float
#     686
#
# KeyboardInterrupt:

# %%
# !python -m pip install "dask[distributed]" --upgrade
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already up-to-date: dask[distributed] in /usr/local/lib/python3.6/dist-packages (2.17.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from dask[distributed]) (5.3.1)
# Collecting distributed>=2.0; extra == "distributed"
#   Downloading https://mirrors.aliyun.com/pypi/packages/40/43/7f0181ff095961f99f436ab0b97239f07f4accb67837783f7ddddb414f32/distributed-2.17.0-py3-none-any.whl (638 kB)
#      |################################| 638 kB 8.4 MB/s eta 0:00:01
# Collecting psutil>=5.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/c4/b8/3512f0e93e0db23a71d82485ba256071ebef99b227351f0f5540f744af41/psutil-5.7.0.tar.gz (449 kB)
#      |################################| 449 kB 13.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "distributed"->dask[distributed]) (1.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "distributed"->dask[distributed]) (46.1.3)
# Requirement already satisfied, skipping upgrade: contextvars; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "distributed"->dask[distributed]) (2.4)
# Collecting click>=6.6
#   Downloading https://mirrors.aliyun.com/pypi/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |################################| 82 kB 5.9 MB/s eta 0:00:011
# Collecting msgpack>=0.6.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/c9/35/33aa1af0700d21beabdf74373f31c52c048be8ee082f98edbc37ba3ae956/msgpack-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (274 kB)
#      |################################| 274 kB 11.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "distributed"->dask[distributed]) (0.10.0)
# Collecting tblib>=1.6.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/0d/de/dca3e651ca62e59c08d324f4a51467fa4b8cbeaafb883b5e83720b4d4a47/tblib-1.6.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: tornado>=5; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "distributed"->dask[distributed]) (6.0.4)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/13/f3/cf85f7c3a2dbd1a515d51e1f1676d971abe41bba6f4ab5443240d9a78e5b/sortedcontainers-2.1.0-py2.py3-none-any.whl (28 kB)
# Collecting zict>=0.1.3
#   Downloading https://mirrors.aliyun.com/pypi/packages/5a/65/0f743c740c30cace984ef8ff96fd1e991083fa884900a8aad3efff3252b9/zict-2.0.0-py3-none-any.whl (10 kB)
# Requirement already satisfied, skipping upgrade: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars; python_version < "3.7"->distributed>=2.0; extra == "distributed"->dask[distributed]) (0.14)
# Collecting heapdict
#   Downloading https://mirrors.aliyun.com/pypi/packages/b6/9d/cd4777dbcf3bef9d9627e0fe4bc43d2e294b1baeb01d0422399d5e9de319/HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: psutil
#   Building wheel for psutil (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ok2n8ov9/psutil/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ok2n8ov9/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-ey9a2ju3
#        cwd: /tmp/pip-install-ok2n8ov9/psutil/
#   Complete output (42 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.6
#   creating build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_pswindows.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psbsd.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_compat.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_common.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psposix.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/__init__.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psaix.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_pslinux.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_pssunos.py -> build/lib.linux-x86_64-3.6/psutil
#   copying psutil/_psosx.py -> build/lib.linux-x86_64-3.6/psutil
#   creating build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_aix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_system.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_bsd.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_connections.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_unicode.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_posix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_windows.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_misc.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_sunos.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/__init__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_memory_leaks.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_osx.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_process.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_linux.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/__main__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_contracts.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   copying psutil/tests/runner.py -> build/lib.linux-x86_64-3.6/psutil/tests
#   running build_ext
#   building 'psutil._psutil_linux' extension
#   creating build/temp.linux-x86_64-3.6
#   creating build/temp.linux-x86_64-3.6/psutil
#   x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DPSUTIL_POSIX=1 -DPSUTIL_SIZEOF_PID_T=4 -DPSUTIL_VERSION=570 -DPSUTIL_LINUX=1 -I/usr/include/python3.6m -c psutil/_psutil_common.c -o build/temp.linux-x86_64-3.6/psutil/_psutil_common.o
#   psutil/_psutil_common.c:9:20: fatal error: Python.h: No such file or directory
#   compilation terminated.
#   error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for psutil
#   Running setup.py clean for psutil
# Failed to build psutil
# Installing collected packages: psutil, click, msgpack, tblib, sortedcontainers, heapdict, zict, distributed
#     Running setup.py install for psutil ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ok2n8ov9/psutil/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ok2n8ov9/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ea_q_hc0/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.6/psutil
#          cwd: /tmp/pip-install-ok2n8ov9/psutil/
#     Complete output (42 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.6
#     creating build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_pswindows.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psbsd.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_compat.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_common.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psposix.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/__init__.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psaix.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_pslinux.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_pssunos.py -> build/lib.linux-x86_64-3.6/psutil
#     copying psutil/_psosx.py -> build/lib.linux-x86_64-3.6/psutil
#     creating build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_aix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_system.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_bsd.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_connections.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_unicode.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_posix.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_windows.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_misc.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_sunos.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/__init__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_memory_leaks.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_osx.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_process.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_linux.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/__main__.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_contracts.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     copying psutil/tests/runner.py -> build/lib.linux-x86_64-3.6/psutil/tests
#     running build_ext
#     building 'psutil._psutil_linux' extension
#     creating build/temp.linux-x86_64-3.6
#     creating build/temp.linux-x86_64-3.6/psutil
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DPSUTIL_POSIX=1 -DPSUTIL_SIZEOF_PID_T=4 -DPSUTIL_VERSION=570 -DPSUTIL_LINUX=1 -I/usr/include/python3.6m -c psutil/_psutil_common.c -o build/temp.linux-x86_64-3.6/psutil/_psutil_common.o
#     psutil/_psutil_common.c:9:20: fatal error: Python.h: No such file or directory
#     compilation terminated.
#     error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ok2n8ov9/psutil/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ok2n8ov9/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ea_q_hc0/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.6/psutil Check the logs for full command output.
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
from dask.diagnostics import ProgressBar
ProgressBar().register()

# %%
from tqdm import tqdm

for i,row in tqdm(df_dask.iterrows(),total=tol):
    item=row['item_id_pred']
    if item in item_ft_list:
        row['item_id_pred_text_vec']=item_feat.loc[item_feat.item_id == item,'text_vec']
        row['item_id_pred_img_vec']=item_feat.loc[item_feat.item_id == item,'img_vec']
    else:
        row['item_id_pred_text_vec']=np.zeros(128)
        row['item_id_pred_img_vec']=np.arange(128)
# Out:
#   0%|          | 0/9536065 [00:00<?, ?it/s]
# [########################################] | 100% Completed |  3.3s
#   0%|          | 7545/9536065 [01:43<36:15:01, 73.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-cba3bccd748d> in <module>
#       5     if item in item_ft_list:
#       6         row['item_id_pred_text_vec']=item_feat.loc[item_feat.item_id == item,'text_vec']
# ----> 7         row['item_id_pred_img_vec']=item_feat.loc[item_feat.item_id == item,'img_vec']
#       8     else:
#       9         row['item_id_pred_text_vec']=np.zeros(128)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      55         result = libops.vec_compare(x.ravel(), y, op)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#      59
#
# KeyboardInterrupt:
